# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
latitudes = np.random.uniform(low=-90.000, high=90.000, size=2000)
longitudes = np.random.uniform(low=-180.000, high=180.000, size=2000)
latitudes_longitudes=zip(latitudes,longitudes)
latitudes_longitudes

# %%
# Add the latitude and longitudes to a list. Unpacking lat_lngs zip object into a list.
coordinates = list(latitudes_longitudes)

# %%
# Create a list for holding the cities.
cities =[]

# Identitfy the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | podgornoye
# Processing Record 3 of Set 1 | kaeng khoi
# Processing Record 4 of Set 1 | karasuk
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | kure
# Processing Record 10 of Set 1 | codrington
# Processing Record 11 of Set 1 | daoukro
# Processing Record 12 of Set 1 | fairbanks
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | haines junction
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | geraldton
# Processing Record 19 of Set 1 | tuatapere
# Processing Record 20 of Set 1 | jalu
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | san patricio
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | lerwick
# Processing Record 29 of Set 1 | cairns
# Processing Record 30 of Set 1 | vostok
# Processing Record 31 of Set 1 | kuito
# Processing Record 32 of Set 1 | los llanos de aridane
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | paamiut
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | grushevskaya
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | robertson
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | sao miguel do tapuio
# Processing Record 43 of Set 1 | sarh
# Processing Record 44 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 1 | jaru
# Processing Record 46 of Set 1 | russell
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | aginskoye
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | hammerfest
# Processing Record 1 of Set 2 | bambanglipuro
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | qaanaaq
# Processing Record 5 of Set 2 | pangnirtung
# Processing Record 6 of Set 2 | dagana
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | keelung
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | lakeway
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | antalaha
# Processing Record 16 of Set 2 | rawson
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | wanning
# Processing Record 19 of Set 2 | hirara
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | dingle
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | wolmaranstad
# City not found. Skipping...
# Processing Record 25 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 2 | hassleholm
# Processing Record 27 of Set 2 | amapa
# Processing Record 28 of Set 2 | denia
# Processing Record 29 of Set 2 | flin flon
# Processing Record 30 of Set 2 | ailigandi
# Processing Record 31 of Set 2 | luanda
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | chuy
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | domoni
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | kavaratti
# Processing Record 40 of Set 2 | iskateley
# Processing Record 41 of Set 2 | gondanglegi
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | port-cartier
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | ushuaia
# Processing Record 48 of Set 2 | amlame
# Processing Record 49 of Set 2 | myre
# Processing Record 50 of Set 2 | kirakira
# Processing Record 1 of Set 3 | jaca
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | praia da vitoria
# Processing Record 4 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | sheridan
# Processing Record 7 of Set 3 | okha
# Processing Record 8 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 3 | quelimane
# Processing Record 10 of Set 3 | dourbali
# Processing Record 11 of Set 3 | bonfim
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | oktyabrskoye
# Processing Record 15 of Set 3 | yumen
# Processing Record 16 of Set 3 | kariapatti
# Processing Record 17 of Set 3 | skjervoy
# Processing Record 18 of Set 3 | eston
# Processing Record 19 of Set 3 | rio gallegos
# Processing Record 20 of Set 3 | atuona
# Processing Record 21 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 3 | kokoda
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | katsuura
# Processing Record 29 of Set 3 | kolokani
# Processing Record 30 of Set 3 | correntina
# Processing Record 31 of Set 3 | kiunga
# Processing Record 32 of Set 3 | masuri
# Processing Record 33 of Set 3 | miyako
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | chapais
# Processing Record 37 of Set 3 | dosso
# Processing Record 38 of Set 3 | pisco
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | kirksville
# Processing Record 41 of Set 3 | te anau
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | manjacaze
# Processing Record 44 of Set 3 | tuktoyaktuk
# Processing Record 45 of Set 3 | yerbogachen
# Processing Record 46 of Set 3 | esperance
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | yanchukan
# City not found. Skipping...
# Processing Record 50 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | tateyama
# Processing Record 2 of Set 4 | poum
# Processing Record 3 of Set 4 | noumea
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | lianyuan
# Processing Record 6 of Set 4 | saint-augustin
# Processing Record 7 of Set 4 | ballitoville
# Processing Record 8 of Set 4 | zyryanovsk
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | muros
# Processing Record 11 of Set 4 | port macquarie
# Processing Record 12 of Set 4 | gat
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 4 | tymovskoye
# Processing Record 16 of Set 4 | dunedin
# Processing Record 17 of Set 4 | torva
# Processing Record 18 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 4 | husavik
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | artigas
# Processing Record 22 of Set 4 | east london
# Processing Record 23 of Set 4 | salinas
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | hervey bay
# Processing Record 26 of Set 4 | harper
# Processing Record 27 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 30 of Set 4 | egvekinot
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | key largo
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | manono
# Processing Record 35 of Set 4 | margate
# Processing Record 36 of Set 4 | nova vicosa
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | senador jose porfirio
# Processing Record 40 of Set 4 | houston
# Processing Record 41 of Set 4 | bambous virieux
# Processing Record 42 of Set 4 | hamilton
# Processing Record 43 of Set 4 | caravelas
# Processing Record 44 of Set 4 | buala
# Processing Record 45 of Set 4 | samarai
# Processing Record 46 of Set 4 | phuket
# Processing Record 47 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 4 | rumoi
# Processing Record 49 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 4 | kruisfontein
# Processing Record 1 of Set 5 | saskylakh
# Processing Record 2 of Set 5 | san quintin
# Processing Record 3 of Set 5 | am timan
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | eyl
# Processing Record 6 of Set 5 | beringovskiy
# Processing Record 7 of Set 5 | labuhan
# Processing Record 8 of Set 5 | kavieng
# Processing Record 9 of Set 5 | sanmenxia
# Processing Record 10 of Set 5 | srednekolymsk
# Processing Record 11 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | arrifes
# Processing Record 14 of Set 5 | kawalu
# Processing Record 15 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 5 | kudahuvadhoo
# Processing Record 17 of Set 5 | vila franca do campo
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | makakilo city
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | kamenka
# Processing Record 22 of Set 5 | bud
# Processing Record 23 of Set 5 | mandan
# Processing Record 24 of Set 5 | guangyuan
# Processing Record 25 of Set 5 | emerald
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | padang
# Processing Record 28 of Set 5 | vanimo
# Processing Record 29 of Set 5 | chokurdakh
# Processing Record 30 of Set 5 | porto walter
# Processing Record 31 of Set 5 | sarahan
# Processing Record 32 of Set 5 | takhtamygda
# Processing Record 33 of Set 5 | perehonivka
# Processing Record 34 of Set 5 | anchorage
# Processing Record 35 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 5 | salinopolis
# Processing Record 37 of Set 5 | orocue
# Processing Record 38 of Set 5 | lianzhou
# Processing Record 39 of Set 5 | marica
# Processing Record 40 of Set 5 | juxian
# City not found. Skipping...
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | lander
# Processing Record 43 of Set 5 | sitka
# Processing Record 44 of Set 5 | muli
# Processing Record 45 of Set 5 | muravlenko
# Processing Record 46 of Set 5 | tongliao
# Processing Record 47 of Set 5 | ohara
# Processing Record 48 of Set 5 | broken hill
# Processing Record 49 of Set 5 | truckee
# Processing Record 50 of Set 5 | clinton
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | galeana
# Processing Record 4 of Set 6 | taltal
# Processing Record 5 of Set 6 | kalmunai
# Processing Record 6 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 6 | xinyang
# Processing Record 8 of Set 6 | mahebourg
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | flinders
# Processing Record 11 of Set 6 | pevek
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | aden
# Processing Record 14 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 15 of Set 6 | nantucket
# Processing Record 16 of Set 6 | andenes
# Processing Record 17 of Set 6 | port alfred
# Processing Record 18 of Set 6 | parkes
# Processing Record 19 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 6 | yeppoon
# Processing Record 21 of Set 6 | filotion
# Processing Record 22 of Set 6 | luwuk
# Processing Record 23 of Set 6 | tautira
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | bonthe
# Processing Record 26 of Set 6 | rijssen
# Processing Record 27 of Set 6 | temiscaming
# Processing Record 28 of Set 6 | urusha
# Processing Record 29 of Set 6 | severo-kurilsk
# Processing Record 30 of Set 6 | darhan
# Processing Record 31 of Set 6 | monchique
# Processing Record 32 of Set 6 | karratha
# Processing Record 33 of Set 6 | ruy barbosa
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | cabedelo
# Processing Record 36 of Set 6 | male
# Processing Record 37 of Set 6 | coahuayana
# Processing Record 38 of Set 6 | ouagadougou
# Processing Record 39 of Set 6 | yantongshan
# Processing Record 40 of Set 6 | gillette
# Processing Record 41 of Set 6 | matara
# Processing Record 42 of Set 6 | zeya
# Processing Record 43 of Set 6 | denpasar
# Processing Record 44 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 45 of Set 6 | rocha
# Processing Record 46 of Set 6 | santo tomas
# Processing Record 47 of Set 6 | georgetown
# Processing Record 48 of Set 6 | kaitangata
# Processing Record 49 of Set 6 | ust-nera
# Processing Record 50 of Set 6 | vicuna
# Processing Record 1 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | marystown
# Processing Record 5 of Set 7 | bacungan
# Processing Record 6 of Set 7 | maceio
# Processing Record 7 of Set 7 | shitanjing
# Processing Record 8 of Set 7 | oudtshoorn
# Processing Record 9 of Set 7 | inuvik
# Processing Record 10 of Set 7 | juneau
# Processing Record 11 of Set 7 | kedrovyy
# Processing Record 12 of Set 7 | soyo
# Processing Record 13 of Set 7 | sao gabriel da cachoeira
# Processing Record 14 of Set 7 | doume
# Processing Record 15 of Set 7 | taoudenni
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | vao
# Processing Record 18 of Set 7 | sistranda
# Processing Record 19 of Set 7 | sao joao da barra
# Processing Record 20 of Set 7 | palana
# Processing Record 21 of Set 7 | gamba
# Processing Record 22 of Set 7 | lishui
# Processing Record 23 of Set 7 | waw
# Processing Record 24 of Set 7 | itoman
# Processing Record 25 of Set 7 | mbandaka
# Processing Record 26 of Set 7 | trairi
# Processing Record 27 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 28 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 7 | conde
# Processing Record 30 of Set 7 | aurora
# Processing Record 31 of Set 7 | olinda
# Processing Record 32 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 7 | jiaonan
# Processing Record 34 of Set 7 | bijie
# Processing Record 35 of Set 7 | nemuro
# Processing Record 36 of Set 7 | inhambane
# Processing Record 37 of Set 7 | tiksi
# Processing Record 38 of Set 7 | brus laguna
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | roma
# Processing Record 41 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 7 | abeche
# Processing Record 43 of Set 7 | aklavik
# Processing Record 44 of Set 7 | namatanai
# Processing Record 45 of Set 7 | port shepstone
# Processing Record 46 of Set 7 | laguna
# Processing Record 47 of Set 7 | beroroha
# Processing Record 48 of Set 7 | haverfordwest
# Processing Record 49 of Set 7 | raudeberg
# Processing Record 50 of Set 7 | fereydun kenar
# Processing Record 1 of Set 8 | uray
# Processing Record 2 of Set 8 | gazanjyk
# Processing Record 3 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 8 | castro
# Processing Record 5 of Set 8 | cockburn town
# Processing Record 6 of Set 8 | poya
# Processing Record 7 of Set 8 | santa maria da vitoria
# Processing Record 8 of Set 8 | bossangoa
# Processing Record 9 of Set 8 | half moon bay
# Processing Record 10 of Set 8 | karasburg
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | mpraeso
# Processing Record 13 of Set 8 | kazminskoye
# City not found. Skipping...
# Processing Record 14 of Set 8 | lumut
# Processing Record 15 of Set 8 | west wendover
# Processing Record 16 of Set 8 | port-gentil
# Processing Record 17 of Set 8 | atar
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | tutoia
# Processing Record 20 of Set 8 | alta floresta
# Processing Record 21 of Set 8 | borovoy
# Processing Record 22 of Set 8 | kumeny
# Processing Record 23 of Set 8 | yangambi
# Processing Record 24 of Set 8 | baherden
# Processing Record 25 of Set 8 | upernavik
# Processing Record 26 of Set 8 | acarau
# Processing Record 27 of Set 8 | aqtobe
# Processing Record 28 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 29 of Set 8 | oistins
# Processing Record 30 of Set 8 | nongstoin
# Processing Record 31 of Set 8 | boshnyakovo
# Processing Record 32 of Set 8 | punta alta
# Processing Record 33 of Set 8 | pemberton
# Processing Record 34 of Set 8 | sungaipenuh
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | palmer
# Processing Record 37 of Set 8 | grafton
# Processing Record 38 of Set 8 | kang
# Processing Record 39 of Set 8 | sangar
# Processing Record 40 of Set 8 | camacha
# Processing Record 41 of Set 8 | mount gambier
# Processing Record 42 of Set 8 | mandalgovi
# Processing Record 43 of Set 8 | tura
# Processing Record 44 of Set 8 | hailar
# Processing Record 45 of Set 8 | scarborough
# Processing Record 46 of Set 8 | mgandu
# Processing Record 47 of Set 8 | sekiyado
# City not found. Skipping...
# Processing Record 48 of Set 8 | perevolotskiy
# Processing Record 49 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 8 | teguise
# Processing Record 1 of Set 9 | kloulklubed
# Processing Record 2 of Set 9 | barra
# Processing Record 3 of Set 9 | kamogawa
# Processing Record 4 of Set 9 | puerto escondido
# Processing Record 5 of Set 9 | tabou
# Processing Record 6 of Set 9 | trelew
# Processing Record 7 of Set 9 | saint-joseph
# Processing Record 8 of Set 9 | bundaberg
# Processing Record 9 of Set 9 | nuuk
# Processing Record 10 of Set 9 | keetmanshoop
# Processing Record 11 of Set 9 | preobrazheniye
# Processing Record 12 of Set 9 | khuzdar
# Processing Record 13 of Set 9 | henties bay
# Processing Record 14 of Set 9 | riyadh
# Processing Record 15 of Set 9 | manzhouli
# Processing Record 16 of Set 9 | ladario
# Processing Record 17 of Set 9 | zhangye
# Processing Record 18 of Set 9 | carauari
# Processing Record 19 of Set 9 | kidal
# Processing Record 20 of Set 9 | orzinuovi
# Processing Record 21 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 9 | honiara
# Processing Record 23 of Set 9 | hofn
# Processing Record 24 of Set 9 | kinna
# Processing Record 25 of Set 9 | samana
# Processing Record 26 of Set 9 | teluk nibung
# Processing Record 27 of Set 9 | hasaki
# Processing Record 28 of Set 9 | beian
# Processing Record 29 of Set 9 | makarov
# Processing Record 30 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 9 | lively
# Processing Record 32 of Set 9 | yarmouth
# Processing Record 33 of Set 9 | lasa
# Processing Record 34 of Set 9 | sola
# Processing Record 35 of Set 9 | merrill
# Processing Record 36 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 9 | ambon
# Processing Record 38 of Set 9 | airai
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | huarmey
# Processing Record 41 of Set 9 | fortuna
# Processing Record 42 of Set 9 | sloboda
# Processing Record 43 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | atkinson
# Processing Record 45 of Set 9 | kyren
# Processing Record 46 of Set 9 | vytegra
# Processing Record 47 of Set 9 | umea
# Processing Record 48 of Set 9 | novoagansk
# Processing Record 49 of Set 9 | iisaku
# Processing Record 50 of Set 9 | otjimbingwe
# Processing Record 1 of Set 10 | alpena
# Processing Record 2 of Set 10 | gambo
# Processing Record 3 of Set 10 | plettenberg bay
# Processing Record 4 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 5 of Set 10 | sambava
# Processing Record 6 of Set 10 | socorro
# Processing Record 7 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 10 | sao filipe
# Processing Record 9 of Set 10 | tena
# Processing Record 10 of Set 10 | show low
# Processing Record 11 of Set 10 | goure
# Processing Record 12 of Set 10 | port hedland
# Processing Record 13 of Set 10 | kisangani
# Processing Record 14 of Set 10 | mareeba
# Processing Record 15 of Set 10 | tessalit
# Processing Record 16 of Set 10 | klaeng
# Processing Record 17 of Set 10 | boa vista
# Processing Record 18 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 10 | hit
# Processing Record 20 of Set 10 | abu dhabi
# Processing Record 21 of Set 10 | creel
# Processing Record 22 of Set 10 | kondagaon
# Processing Record 23 of Set 10 | verkhnevilyuysk
# Processing Record 24 of Set 10 | adrar
# Processing Record 25 of Set 10 | zambezi
# Processing Record 26 of Set 10 | toora-khem
# Processing Record 27 of Set 10 | abadan
# Processing Record 28 of Set 10 | batemans bay
# Processing Record 29 of Set 10 | patiya
# Processing Record 30 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 10 | silchar
# Processing Record 32 of Set 10 | tezpur
# Processing Record 33 of Set 10 | villacarrillo
# Processing Record 34 of Set 10 | bonavista
# Processing Record 35 of Set 10 | melfort
# Processing Record 36 of Set 10 | giyani
# Processing Record 37 of Set 10 | lompoc
# Processing Record 38 of Set 10 | gallup
# Processing Record 39 of Set 10 | malartic
# Processing Record 40 of Set 10 | sakhipur
# Processing Record 41 of Set 10 | akyab
# Processing Record 42 of Set 10 | maragogi
# Processing Record 43 of Set 10 | vikulovo
# Processing Record 44 of Set 10 | waipawa
# Processing Record 45 of Set 10 | malibu
# Processing Record 46 of Set 10 | nioro
# Processing Record 47 of Set 10 | tupelo
# Processing Record 48 of Set 10 | ayagoz
# Processing Record 49 of Set 10 | mbuji-mayi
# Processing Record 50 of Set 10 | grand gaube
# Processing Record 1 of Set 11 | lufilufi
# Processing Record 2 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 11 | redlands
# Processing Record 4 of Set 11 | shelburne
# Processing Record 5 of Set 11 | kununurra
# Processing Record 6 of Set 11 | qingdao
# Processing Record 7 of Set 11 | inirida
# Processing Record 8 of Set 11 | krasnoshchekovo
# Processing Record 9 of Set 11 | yar-sale
# Processing Record 10 of Set 11 | kedougou
# Processing Record 11 of Set 11 | puerto madryn
# Processing Record 12 of Set 11 | lavrentiya
# Processing Record 13 of Set 11 | semey
# Processing Record 14 of Set 11 | ondjiva
# Processing Record 15 of Set 11 | itanhaem
# Processing Record 16 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 11 | nicolas bravo
# Processing Record 18 of Set 11 | zhigansk
# Processing Record 19 of Set 11 | port hueneme
# Processing Record 20 of Set 11 | manhattan
# Processing Record 21 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 11 | huangchuan
# Processing Record 23 of Set 11 | tucuma
# Processing Record 24 of Set 11 | tual
# Processing Record 25 of Set 11 | kostomuksha
# Processing Record 26 of Set 11 | wagga wagga
# Processing Record 27 of Set 11 | kondinskoye
# Processing Record 28 of Set 11 | qaqortoq
# Processing Record 29 of Set 11 | conceicao do araguaia
# Processing Record 30 of Set 11 | teknaf
# Processing Record 31 of Set 11 | acapulco
# Processing Record 32 of Set 11 | victor harbor
# Processing Record 33 of Set 11 | xining
# Processing Record 34 of Set 11 | faanui
# Processing Record 35 of Set 11 | cururupu
# Processing Record 36 of Set 11 | port keats
# Processing Record 37 of Set 11 | pitimbu
# Processing Record 38 of Set 11 | moog
# Processing Record 39 of Set 11 | monrovia
# Processing Record 40 of Set 11 | tonantins
# Processing Record 41 of Set 11 | phitsanulok
# Processing Record 42 of Set 11 | dudinka
# Processing Record 43 of Set 11 | savona
# Processing Record 44 of Set 11 | hannibal
# Processing Record 45 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 46 of Set 11 | troitskoye
# Processing Record 47 of Set 11 | berbera
# Processing Record 48 of Set 11 | jieshi
# Processing Record 49 of Set 11 | kilindoni
# Processing Record 50 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 12 | luganville
# Processing Record 2 of Set 12 | saveh
# Processing Record 3 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 12 | vanderhoof
# Processing Record 5 of Set 12 | manacapuru
# Processing Record 6 of Set 12 | okhotsk
# Processing Record 7 of Set 12 | hobyo
# Processing Record 8 of Set 12 | vardo
# Processing Record 9 of Set 12 | doha
# Processing Record 10 of Set 12 | siniscola
# Processing Record 11 of Set 12 | robertsport
# Processing Record 12 of Set 12 | marsh harbour
# Processing Record 13 of Set 12 | raga
# Processing Record 14 of Set 12 | umm lajj
# Processing Record 15 of Set 12 | beloha
# Processing Record 16 of Set 12 | prince rupert
# Processing Record 17 of Set 12 | paka
# Processing Record 18 of Set 12 | asau
# Processing Record 19 of Set 12 | sao jose da coroa grande
# Processing Record 20 of Set 12 | ngorongoro
# Processing Record 21 of Set 12 | dobric
# Processing Record 22 of Set 12 | la ronge
# Processing Record 23 of Set 12 | dalaba
# Processing Record 24 of Set 12 | natal
# Processing Record 25 of Set 12 | iquique
# Processing Record 26 of Set 12 | ulaangom
# Processing Record 27 of Set 12 | linhares
# Processing Record 28 of Set 12 | hede
# Processing Record 29 of Set 12 | balakhninskiy
# Processing Record 30 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 31 of Set 12 | deputatskiy
# Processing Record 32 of Set 12 | shawnee
# Processing Record 33 of Set 12 | fushe-arrez
# Processing Record 34 of Set 12 | nome
# Processing Record 35 of Set 12 | san cristobal
# Processing Record 36 of Set 12 | cortez
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | port blair
# Processing Record 39 of Set 12 | grindavik
# Processing Record 40 of Set 12 | starkville
# Processing Record 41 of Set 12 | saint anthony
# Processing Record 42 of Set 12 | eenhana
# Processing Record 43 of Set 12 | lata
# Processing Record 44 of Set 12 | loikaw
# Processing Record 45 of Set 12 | hermiston
# Processing Record 46 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 12 | tomohon
# Processing Record 48 of Set 12 | barsovo
# Processing Record 49 of Set 12 | saint-louis
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | santa helena
# Processing Record 2 of Set 13 | vangaindrano
# Processing Record 3 of Set 13 | quatre cocos
# Processing Record 4 of Set 13 | defiance
# Processing Record 5 of Set 13 | alice springs
# Processing Record 6 of Set 13 | solsvik
# City not found. Skipping...
# Processing Record 7 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 13 | kodinsk
# Processing Record 9 of Set 13 | iberia
# Processing Record 10 of Set 13 | mananjary
# Processing Record 11 of Set 13 | pontianak
# Processing Record 12 of Set 13 | linqing
# Processing Record 13 of Set 13 | itainopolis
# Processing Record 14 of Set 13 | orangeburg
# Processing Record 15 of Set 13 | macamic
# Processing Record 16 of Set 13 | high prairie
# Processing Record 17 of Set 13 | pop
# Processing Record 18 of Set 13 | coffs harbour
# Processing Record 19 of Set 13 | barnstead
# Processing Record 20 of Set 13 | phan thiet
# Processing Record 21 of Set 13 | astoria
# Processing Record 22 of Set 13 | oga
# Processing Record 23 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 13 | nicoya
# Processing Record 25 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 27 of Set 13 | kerman
# Processing Record 28 of Set 13 | pouebo
# Processing Record 29 of Set 13 | itaituba
# Processing Record 30 of Set 13 | setermoen
# Processing Record 31 of Set 13 | markova
# Processing Record 32 of Set 13 | pacific grove
# Processing Record 33 of Set 13 | akdepe
# Processing Record 34 of Set 13 | anshun
# Processing Record 35 of Set 13 | zyryanka
# Processing Record 36 of Set 13 | kohlu
# Processing Record 37 of Set 13 | coihaique
# Processing Record 38 of Set 13 | myitkyina
# Processing Record 39 of Set 13 | barra patuca
# Processing Record 40 of Set 13 | shenjiamen
# Processing Record 41 of Set 13 | plum
# Processing Record 42 of Set 13 | banda aceh
# Processing Record 43 of Set 13 | hovd
# Processing Record 44 of Set 13 | ranfurly
# Processing Record 45 of Set 13 | santa catarina de tepehuanes
# Processing Record 46 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 13 | ponta delgada
# Processing Record 48 of Set 13 | oum hadjer
# Processing Record 49 of Set 13 | edd
# Processing Record 50 of Set 13 | edinburg
# Processing Record 1 of Set 14 | huaiyin
# Processing Record 2 of Set 14 | wana
# Processing Record 3 of Set 14 | erenhot
# Processing Record 4 of Set 14 | cayenne
# Processing Record 5 of Set 14 | abha
# Processing Record 6 of Set 14 | klamath falls
# Processing Record 7 of Set 14 | sulmona
# Processing Record 8 of Set 14 | hayden
# Processing Record 9 of Set 14 | burica
# City not found. Skipping...
# Processing Record 10 of Set 14 | tucumcari
# Processing Record 11 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | smolenka
# Processing Record 14 of Set 14 | adre
# Processing Record 15 of Set 14 | santa fe
# Processing Record 16 of Set 14 | idaho falls
# Processing Record 17 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 18 of Set 14 | kharan
# Processing Record 19 of Set 14 | amahai
# Processing Record 20 of Set 14 | cernosice
# Processing Record 21 of Set 14 | orlik
# Processing Record 22 of Set 14 | bohodukhiv
# Processing Record 23 of Set 14 | havoysund
# Processing Record 24 of Set 14 | sinnamary
# Processing Record 25 of Set 14 | raton
# Processing Record 26 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 27 of Set 14 | kuzhithurai
# Processing Record 28 of Set 14 | alice town
# Processing Record 29 of Set 14 | nakhon luang
# Processing Record 30 of Set 14 | pozo colorado
# Processing Record 31 of Set 14 | dhidhdhoo
# Processing Record 32 of Set 14 | naryan-mar
# Processing Record 33 of Set 14 | pak phanang
# Processing Record 34 of Set 14 | chippewa falls
# Processing Record 35 of Set 14 | ugoofaaru
# Processing Record 36 of Set 14 | ankazoabo
# Processing Record 37 of Set 14 | biltine
# Processing Record 38 of Set 14 | oktyabrskiy
# Processing Record 39 of Set 14 | lagoa
# Processing Record 40 of Set 14 | ixtapa
# Processing Record 41 of Set 14 | matale
# Processing Record 42 of Set 14 | rosetta
# Processing Record 43 of Set 14 | peachland
# Processing Record 44 of Set 14 | pangkalanbuun
# Processing Record 45 of Set 14 | betare oya
# Processing Record 46 of Set 14 | lagunas
# Processing Record 47 of Set 14 | taunggyi
# Processing Record 48 of Set 14 | san ignacio
# Processing Record 49 of Set 14 | baykit
# Processing Record 50 of Set 14 | kichera
# Processing Record 1 of Set 15 | gumusyaka
# City not found. Skipping...
# Processing Record 2 of Set 15 | chaman
# Processing Record 3 of Set 15 | kathmandu
# Processing Record 4 of Set 15 | faya
# Processing Record 5 of Set 15 | bismarck
# Processing Record 6 of Set 15 | pimentel
# Processing Record 7 of Set 15 | bahia blanca
# Processing Record 8 of Set 15 | san ramon
# Processing Record 9 of Set 15 | vestmannaeyjar
# Processing Record 10 of Set 15 | sinegorsk
# Processing Record 11 of Set 15 | maniitsoq
# Processing Record 12 of Set 15 | canutama
# Processing Record 13 of Set 15 | bogo
# Processing Record 14 of Set 15 | bathsheba
# Processing Record 15 of Set 15 | seymchan
# Processing Record 16 of Set 15 | kautokeino
# Processing Record 17 of Set 15 | portland
# Processing Record 18 of Set 15 | rossland
# Processing Record 19 of Set 15 | liberal
# Processing Record 20 of Set 15 | coihueco
# Processing Record 21 of Set 15 | jesup
# Processing Record 22 of Set 15 | black forest
# Processing Record 23 of Set 15 | terney
# Processing Record 24 of Set 15 | sakakah
# Processing Record 25 of Set 15 | salta
# Processing Record 26 of Set 15 | springbok
# Processing Record 27 of Set 15 | leshukonskoye
# Processing Record 28 of Set 15 | moose factory
# Processing Record 29 of Set 15 | chemainus
# Processing Record 30 of Set 15 | kungurtug
# Processing Record 31 of Set 15 | howard springs
# Processing Record 32 of Set 15 | meiganga
# Processing Record 33 of Set 15 | rawa mazowiecka
# Processing Record 34 of Set 15 | sioux lookout
# Processing Record 35 of Set 15 | upington
# Processing Record 36 of Set 15 | kieta
# Processing Record 37 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 15 | mehamn
# Processing Record 39 of Set 15 | nagato
# Processing Record 40 of Set 15 | haapiti
# Processing Record 41 of Set 15 | mogadishu
# Processing Record 42 of Set 15 | carballo
# Processing Record 43 of Set 15 | tiznit
# Processing Record 44 of Set 15 | iroquois falls
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 675

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_data_df = pd.DataFrame(city_data)
city_weather_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Victoria      HK  22.2855  114.1577     87.33        83          10
# 1      Podgornoye      RU  51.7350   39.1496     84.42        32           0
# 2      Kaeng Khoi      TH  14.5862  100.9976     82.98        89         100
# 3         Karasuk      RU  53.7377   78.0403     71.55        60          84
# 4         Rikitea      PF -23.1203 -134.9692     74.70        78         100
# 5  Saint-Philippe      RE -21.3585   55.7679     69.39        77          31
# 6     Clyde River      CA  70.4692  -68.5914     43.03        75          20
# 7            Kure      JP  34.2333  132.5667     80.53        90          99
# 8      Codrington      AU -38.2667  141.9667     43.50        92           1
# 9         Daoukro      CI   7.0591   -3.9631     75.02        97         100
#
#    Wind Speed   Current Description
# 0       13.00             clear sky
# 1        6.71             clear sky
# 2        6.44  heavy intensity rain
# 3        9.51         broken clouds
# 4       14.20            light rain
# 5       15.57      scattered clouds
# 6        4.61            few clouds
# 7        1.63       overcast clouds
# 8        7.25             clear sky
# 9        5.46         moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_weather_data into a CSV.
city_weather_data_df.to_csv(output_data_file, index_label="City_ID")
